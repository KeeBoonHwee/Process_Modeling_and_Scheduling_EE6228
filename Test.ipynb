# %%
# !pip list

# %%
# https://personal.ntu.edu.sg/rsu/Downloads.htm
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
sys.path.append('./SuSyNA')
sys.path.append('./SuSyNA/automata')

# %%
np.set_printoptions(linewidth=np.inf)
# np.set_printoptions(formatter={'float': lambda x: f"{round(x):5.0f}"}, suppress=True)

# %%
pd.set_option('display.width', None)
pd.set_option('display.max_columns', None)

# %%
from SuSyNA.make_get_size     import MakeGetSizeApplication
from SuSyNA.automata.frontend import CmdParm, EXIST_AUT

# %% [markdown]
# C:\Python27\python.exe SuSyNA\make_get_size.py SusyNA\automata\b1.cfg

# %%
# C:\Python27\python.exe SuSyNA\make_get_size.py SusyNA\automata\b1.cfg
try:
    app = MakeGetSizeApplication()
    args = {}
    args['aut_name'] = './SusyNA/automata/b1.cfg'
     
    app.main(args)
    
except Exception as e:
    print(e)
# Out:
# ("args['aut_name']", './SusyNA/automata/b1.cfg')
# Mon Feb 16 18:53:41 2026: Started calculating size (version 0.4.4)	(memory=83431424 bytes)
# Number of states: 3
# Number of transitions: 8
